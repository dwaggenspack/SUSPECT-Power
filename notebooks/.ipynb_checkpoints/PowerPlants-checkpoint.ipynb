# %%
import geopandas as gpd
import pandas as pd
import numpy
import fiona

# %%
pplants = gpd.read_file(r'.\data\PowerPlants_US_EIA\PowerPlants_US_202001.shp')

# %%
pplants['combine'] = pplants[['Total_MW','Coal_MW','NG_MW','Crude_MW','Bio_MW','Hydro_MW','HydroPS_MW','Nuclear_MW','Solar_MW','Wind_MW','Geo_MW','Bat_MW','Other_MW']].values.tolist()

# %%
pplants.head(3)
# Out:
#    Plant_Code          Plant_Name        Utility_Na  Utility_ID  \
# 0           2        Bankhead Dam  Alabama Power Co         195
# 1           3               Barry  Alabama Power Co         195
# 2           4  Walter Bouldin Dam  Alabama Power Co         195
#
#          sector_nam       City      County StateName    Zip  \
# 0  Electric Utility  Northport  Tuscaloosa   Alabama  35476
# 1  Electric Utility      Bucks      Mobile   Alabama  36512
# 2  Electric Utility   Wetumpka      Elmore   Alabama  36092
#
#              Street_Add  ... Bat_MW  Other_MW  \
# 0    19001 Lock 17 Road  ...   None      None
# 1      North Highway 43  ...   None      None
# 2  750 Bouldin Dam Road  ...   None      None
#
#                                   source_des  \
# 0                      Hydroelectric = 53 MW
# 1  Coal = 1118.5 MW, Natural Gas = 1268.4 MW
# 2                   Hydroelectric = 224.1 MW
#
#                                            tech_desc  \
# ...

# %%
pd.DataFrame([dict([kv.split(' = ') for kv in record.split(', ')]) for record in pplants[['source_des']]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-98e9f7822d3a> in <module>
# ----> 1 pd.DataFrame([dict([kv.split(' = ') for kv in record.split(', ')]) for record in pplants[['source_des']]])
#
# <ipython-input-49-98e9f7822d3a> in <listcomp>(.0)
# ----> 1 pd.DataFrame([dict([kv.split(' = ') for kv in record.split(', ')]) for record in pplants[['source_des']]])
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
pplants['test'] = pplants['source_des'].str.split(", ", n = -1, expand = False)

# %%
res = dict(item.split(" = ") for item in (pplants['source_des'].str.split(","))
# Out:
#   File "<ipython-input-62-af70343984a2>", line 1
#     res = dict(item.split(" = ") for item in (pplants['source_des'].str.split(","))
#                                                                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
pplants['fuel'] = pplants.source_des.str.split(',',expand=False)

# %%
pplants.head(3)
# Out:
#    Plant_Code          Plant_Name        Utility_Na  Utility_ID  \
# 0           2        Bankhead Dam  Alabama Power Co         195
# 1           3               Barry  Alabama Power Co         195
# 2           4  Walter Bouldin Dam  Alabama Power Co         195
#
#          sector_nam       City      County StateName    Zip  \
# 0  Electric Utility  Northport  Tuscaloosa   Alabama  35476
# 1  Electric Utility      Bucks      Mobile   Alabama  36512
# 2  Electric Utility   Wetumpka      Elmore   Alabama  36092
#
#              Street_Add  ... Other_MW  \
# 0    19001 Lock 17 Road  ...     None
# 1      North Highway 43  ...     None
# 2  750 Bouldin Dam Road  ...     None
#
#                                   source_des  \
# 0                      Hydroelectric = 53 MW
# 1  Coal = 1118.5 MW, Natural Gas = 1268.4 MW
# 2                   Hydroelectric = 224.1 MW
#
#                                            tech_desc  \
# 0                         Conventional Hydroelectric
# ...

# %%
for item in pplants['fuel'] (dict(item.split("=") )
# Out:
#   File "<ipython-input-65-2f6aadbfeb78>", line 1
#     for item in pplants['fuel'].str (dict(item.split(" = ") )
#                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
(pplants['source_des'].str.split(","))
# Out:
# 0                            [Hydroelectric = 53 MW]
# 1       [Coal = 1118.5 MW,  Natural Gas = 1268.4 MW]
# 2                         [Hydroelectric = 224.1 MW]
# 3                             [Natural Gas = 130 MW]
# 4                              [Natural Gas = 63 MW]
#                             ...
# 9763                                [Solar = 1.4 MW]
# 9764                                [Solar = 1.9 MW]
# 9765                                  [Solar = 2 MW]
# 9766                                  [Solar = 2 MW]
# 9767                                  [Solar = 2 MW]
# Name: source_des, Length: 9768, dtype: object
